# %% [markdown]
# ## Structure DataFrames generated from doesthedogdie Open API

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import sys
sys.path.append('../utils')
import functions

# %%
howl_df = pd.read_csv('../data/raw/single_titles/howls_moving_castle_df.csv')
howl_df.head()

# %%
# functions.show_basic_info(howl_df)

# %%
# functions.show_column_value_counts(howl_df, 'event_description')

# %%
# print(howl_df['event_description'].unique())

# %% [markdown]
# ## Create sub categories for content warning
# - Reduce rows from 197 to 10
# - add yes_count and no_count and display sum

# %% [markdown]
# ### Categories and Keywords
#
# #### Physical Violence & Harm
# - beaten
# - stabbed
# - break a bone
# - torture
# - drown
# - choked
# - hit by a car
# - plane crash
# - car crash
# - burned alive
#
# #### Sexual Violence & Abuse
# - sexually assaulted
# - rape
# - virginity
# - objectified
# - abused with a belt
# - sexual assault
# - groped
# - molested
#
# #### Animal Harm
# - dog die
# - cat die
# - animals abused
# - rabbits harmed
# - pet die
# - animal mistreated
# - dog fighting
#
# #### Mental Health & Emotional Abuse
# - gaslighted
# - PTSD
# - mental illness
# - self harm
# - emotional abuse
# - depression
# - anxiety
# - psychological distress
#
# #### Child Abuse & Harm
# - child abused
# - kid die
# - baby cry
# - child death
# - infant abduction
# - child neglect
#
# #### Discrimination & Social Justice Issues
# - racist
# - homophobic slurs
# - misgendered
# - blackface
# - minority is misrepresented
# - transphobic
# - ableist
#
# #### Death, Trauma & Grief
# - death
# - suicide
# - trauma
# - loss
# - grief
# - dead
# - funeral
# - body found
# - deceased
#
# #### Addiction & Substance Abuse
# - alcohol abuse
# - drug abuse
# - overdose
# - addiction
# - substance abuse
# - alcoholism
#
# #### Body Horror & Gore
# - gore
# - body horror
# - decapitation
# - mutilation
# - blood
# - amputation
# - cut
# - injury
#
# #### Supernatural & Psychological Disturbance
# - ghosts
# - possession
# - paranoia
# - unhinged
# - dissociation
# - depersonalization
# - derealization
# - supernatural
# - psychotic

# %%
# make copy
howl_category_df = howl_df.copy()

# categories and keywords
categories = {
    'Physical Violence': [
        'beaten', 'stabbed', 'break a bone', 'torture', 'drown', 'choked', 'hit by a car', 'plane crash', 'car crash', 'kidnapped', 'hands damaged', 'struggle to breathe',
        'burned alive', 'gun violence', 'decapitation', 'fall down stairs', 'head get squashed', 'injury', 'mutilation', 'buried alive', '9/11',
        'blood', 'cut', 'amputation', 'teeth damaged', 'fall to their death', 'crushed to death', 'body horror', 'genital trauma', 'hanging', 'restrained', 'asphyxiate', 'become unconscious', 'explosion', 'held under water', 'mouth covered'
    ],
    'Sexual Assault & Abuse': [
        'sexually assaulted', 'rape', 'virginity', 'objectified', 'abused with a belt', 'groped', 'large age gap', 'sexual assault', 
        'molested', 'woman brutalized', 'domestic violence', 'woman get slapped', 'sexual content', 'incestuous relationships',
        'sexualized', 'BDSM', 'genital mutilation', 'abused sexually', 'torture', 'non-consensual', 'grooming', 'drugged', 'watched without knowing'
    ],
    'Animal Abuse & Harm': [
        'dog die', 'cat die', 'animals abused', 'rabbits harmed', 'pet die', 'animal mistreated', 'dog fighting', 'animal sad', 'animal die',
        'horse die', 'animals harmed', 'dragon die', 'animal abandoned', 'bestiality', 'pets harmed', 'non-human character die'
    ],
    'Mental Health & Abuse': [
        'gaslighted', 'PTSD', 'mental illness', 'self harm', 'emotional abuse', 'depression', 'anxiety', 'psychological distress', 'r-slur',
        'electro-therapy', 'mental institution scene', 'autism misrepresented', 'mentally ill person violent', 'autism specific abuse', 'someone disabled played by able-bodied',
        'eating disorder', 'dissociation', 'depersonalization', 'derealization', 'body dysphoria', 'body dysmorphia', 'abuse', 'ABA therapy',
        'psychotic', 'addiction', 'substance abuse', 'meltdown', 'anxiety attack', 'claustrophobic scene', 'D.I.D. misrepresentation'
    ],
    'Child Abuse': [
        'child abused', 'kid die', 'baby cry', 'child death', 'infant abduction', 'child neglect', 'child abandoned', 'abusive parents', 'parent die', 'baby stillborn',
        'pedophilia', 'infant abducted', 'minor sexualized', 'sexualized', 'child abandonment', 'toy destroyed', 'babies or unborn children'
    ],
    'Discrimination & Social Issues': [
        'racist', 'homophobic slurs', 'misgendered', 'blackface', 'minority is misrepresented', 'transphobic', 'ableist', 'hate speech', 'homeless', 
        'LGBT+ phobia', 'transphobic slurs', 'racism', 'ableism', 'microaggressions', 'anti-LGBTQ', 'n-word', 'man in a dress', 'antisemitism', 'copaganda', 'incarceration'
    ],
    'Death & Grief': [
        'death', 'suicide', 'trauma', 'loss', 'grief', 'dead', 'funeral', 'body found', 'deceased', 'terminally ill', 'funeral scene', 'family member die', 'kill myself',
        'dying', 'sacrifice', 'miscarriage', 'stillbirth', 'suicide attempt', 'suffering', 'dying in pain', 'sudden death', 'someone die', 'character die', 'person die', '9/11'
    ],
    'Addiction & Substance Abuse': [
        'alcohol abuse', 'drug abuse', 'overdose', 'addiction', 'substance abuse', 'alcoholism', 'abuse alcohol', 'use drugs', 'smoking',
        'drug addiction', 'substance dependence', 'overdose scene', 'drugged'
    ],
    'Body Horror & Gore': [
        'gore', 'body horror', 'decapitation', 'mutilation', 'blood', 'amputation', 'cut', 'injury', 'cannibalism', 'head gets squashed',
        'teeth damaged', 'fall down stairs', 'is someone eaten', 'torture', 'eye mutilation', 'stabbing', 'genital mutilation', 'choking',
        'shaving/cutting', 'dislocations', 'bludgeoning', 'disembowelment', 'vomit', 'on-screen pooping'
    ],
    'Supernatural & Psychological Horror': [
        'ghosts', 'possession', 'paranoia', 'unhinged', 'dissociation', 'depersonalization', 'derealization', 'supernatural', 'psychotic',
        'someone possessed', 'demons or Hell', 'haunting', 'psychological thriller', 'hallucinations', 'nightmares', 'stalked', 'scream', 'jump scares'
    ],
    'Racism & Discrimination': [
        'racism', 'hate speech', 'microaggressions', 'racial slurs', 'minority is misrepresented', 'blackface', 'colorism', 'racial profiling',
        'systemic racism', 'stereotypes', 'reverse racism', 'the black guy dies first', 'n-word', 'antisemitism', 'copaganda', 'black guy die first'
    ],
    'LGBTQ+ Phobia & Gender Issues': [
        'transphobic', 'homophobic slurs', 'misgendered', 'LGBT+ phobia', 'hate speech', 'homophobia', 'transphobic slurs', 'deadnaming', 'LGBT+ person outed',
        'outings', 'anti-LGBTQ', 'queerphobia', 'bi-phobia', 'lesbophobia', 'transphobic humor', 'lesbian erasure', 'bi-erasure', 'LGBT person die', 'man in a dress', 'trans person depicted predatorily', 'bisexual cheating'
    ],
    'Nudity & Sexual Content': [
        'nudity', 'nude scenes', 'sexual content', 'sex scenes', 'sensual', 'implied nudity', 'full nudity', 'sexualized', 'incestuous',
        'intimacy', 'sexual relations', 'gendered nudity', 'unnecessary nudity', 'sexy scenes', 'suggestive content', 'sexual humor'
    ],
    'Ableism & Disability Misrepresentation': [
        'ableist', 'disability discrimination', 'disabled misrepresentation', 'disability abuse', 'disability shaming', 'abled-bodied actor', 'r-slur',
        'crippling', 'mental disability mockery', 'disability jokes', 'non-disabled actor playing disabled role', 'dementia/Alzheimer', 'ABA therapy', 'someone disabled played by able-bodied'
    ],
    'Phobias & Fears': [
        'arachnophobia', 'claustrophobia', 'agoraphobia', 'acrophobia', 'fear of heights', 'fear of water', 'fear of enclosed spaces',
        'fear of germs', 'fear of darkness', 'fear of flying', 'fear of clowns', 'fear of snakes', 'fear of dogs', 'fear of spiders',
        'fear of public speaking', 'fear of death', 'fear of the unknown', 'clowns', 'mannequins', 'misophonia', 'trypophobic', 'razors', 'natural bodies of water', 'aphobia',
        'spiders', 'snakes', 'bugs'
    ],
    'Medical & Hospital Scenes': [
        'hospital scene', 'syringe', 'injection', 'needle', 'electro-therapy', 'doctor', 'nurse', 'ICU', 'surgery', 'diagnosis', 'seizure', 'razors',
        'diagnosed', 'ambulance', 'medical emergency', 'treatment', 'prescription', 'physical therapy', 'rehab', 'medication', 'cancer', 'miscarry', 'abortions', 'childbirth',
        'medical procedure', 'blood transfusion', 'intensive care', 'healthcare', 'medical tests', 'medical examination', 'anti-abortion', 'dementia/Alzheimer', 'chronic illness', 'stroke'
    ],
    'Body Shaming & Fatphobia': [
        'body shaming', 'fatphobia', 'fat shamed', 'weight shaming', 'skinny shaming', 'fat jokes', 'dieting', 'weight loss',
        'body image', 'obesity', 'body standards', 'being called fat', 'fatphobic comments', 'slim shaming', 'size discrimination',
        'appearance-based bullying', 'unrealistic body expectations', 'shamed for eating', 'fat suits'
    ],
    'Sensory Sensitivity': [
        'flashing lights', 'loud noises', 'jump scare', 'shakey cam', 'honk', 'screech', 'loud', 'scream'
    ]
}

# categorize 'event_description'
def categorize_event(description):
    for category, keywords in categories.items():
        if any(keyword.lower() in description.lower() for keyword in keywords):
            return category
    return 'Other'  # default if no match

howl_category_df['category'] = howl_category_df['event_description'].apply(categorize_event)

# Group by category and sum the yes_count and no_count columns
category_sums = howl_category_df.groupby('category')[['yes_count', 'no_count']].sum().reset_index()

# Merge the summed values back into the original DataFrame
howl_category_df = pd.merge(howl_category_df, category_sums, on='category', suffixes=('', '_sum'))

# Show the updated DataFrame with summed counts
# print(howl_df)

# %%
# get unique values in 'Other' category
unique_values_other = howl_category_df[howl_category_df['category'] == 'Other']['event_description'].unique()
print(howl_category_df[howl_category_df['category'] == 'Other']['event_description'].nunique())

print("\nUnique values in category 'Other':\n")
print(unique_values_other)

# %%
howl_category_df = howl_category_df.drop(columns=['event_description', 'yes_count', 'no_count'])
howl_category_df = functions.remove_duplicates(howl_category_df)

# %%
howl_category_df.head(20)
